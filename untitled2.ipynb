# %% [markdown]
# <a href="https://colab.research.google.com/github/dilipjeengar2/macine-learning-task-/blob/main/untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#step 1 : import library
import pandas as pd

# %%
#import data
pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Salary%20Data.csv')
# Out:
#     Experience Years  Salary
# 0                1.1   39343
# 1                1.2   42774
# 2                1.3   46205
# 3                1.5   37731
# 4                2.0   43525
# 5                2.2   39891
# 6                2.5   48266
# 7                2.9   56642
# 8                3.0   60150
# 9                3.2   54445
# 10               3.2   64445
# 11               3.5   60000
# 12               3.7   57189
# 13               3.8   60200
# 14               3.9   63218
# 15               4.0   55794
# 16               4.0   56957
# 17               4.1   57081
# 18               4.3   59095
# 19               4.5   61111
# 20               4.7   64500
# 21               4.9   67938
# 22               5.1   66029
# 23               5.3   83088
# 24               5.5   82200
# 25               5.9   81363
# 26               6.0   93940
# 27               6.2   91000
# 28               6.5   90000
# 29               6.8   91738
# 30               7.1   98273
# ...

# %%
salary = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Salary%20Data.csv')

# %%
salary.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
salary.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
#define target(y) and features (x)
salary.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
salary.shape
# Out:
# (40, 2)

# %%
y = salary['Salary']
x = salary[['Experience Years']]

# %%
# split data
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,train_size = 0.8,random_state=2529)
x_train
# Out:
#     Experience Years
# 17               4.1
# 12               3.7
# 1                1.2
# 6                2.5
# 28               6.5
# 31               7.9
# 34               8.7
# 20               4.7
# 4                2.0
# 3                1.5
# 18               4.3
# 26               6.0
# 2                1.3
# 22               5.1
# 35               9.0
# 7                2.9
# 39              10.5
# 30               7.1
# 10               3.2
# 0                1.1
# 9                3.2
# 13               3.8
# 5                2.2
# 37               9.6
# 23               5.3
# 25               5.9
# 21               4.9
# 24               5.5
# 8                3.0
# 36               9.5
# 15               4.0
# 32               8.2

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((32, 1), (8, 1), (32,), (8,))

# %%
# select model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# train model (fit model)
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 26344.85810217697

# %%
model.coef_
# Out:
# array([9398.19785815])

# %%
# model prediction
y_pred=model.predict(x_test)

# %%
x_test
# Out:
#     Experience Years
# 29               6.8
# 11               3.5
# 33               8.5
# 16               4.0
# 19               4.5
# 38              10.3
# 27               6.2
# 14               3.9

# %%
# accuracy of model
from sklearn.metrics import mean_absolute_percentage_error

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.050339688879149136
